# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic= pd.read_csv('/Users/bhanu/Downloads/1950052-Sales_Data/Titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
titanic.shape
# Out:
# (418, 11)

# %%
titanic.head(4)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
# 3          895       3                  Wirz, Mr. Albert    male  27.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q
# 3      0  315154  8.6625   NaN        S

# %%
sales = pd.read_csv('/Users/bhanu/Downloads/1950052-Sales_Data/Sales_Data.csv')

# %%
sales
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
sales.shape
# Out:
# (5000, 14)

# %%
sales['Region'].value_counts()
# Out:
# Region
# Europe                               1330
# Sub-Saharan Africa                   1285
# Asia                                  719
# Middle East and North Africa          610
# Central America and the Caribbean     534
# Australia and Oceania                 416
# North America                         106
# Name: count, dtype: int64

# %% [markdown]
# ### plot.bar

# %%
sales['Region'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
sns.countplot(x='Region',data=sales,)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize=(15,4))
plt.title('number of order of the region')
sns.countplot(x='Region',data=sales)
# Out:
# <Axes: title={'center': 'number of order of the region'}, xlabel='Region', ylabel='count'>

# %%
colour = sns.color_palette("cubehelix")
plt.figure(figsize=(10,5))
sns.countplot(x='Region', data=sales, palette=colour)
plt.title('Number of Orders by Region')
plt.ylabel('Number of Orders')
plt.xlabel('Unit_MakingCost')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
colour = sns.color_palette("cubehelix")
plt.figure(figsize=(10,5))
sns.countplot(x='Total_Revenue', data=sales, palette=colour)
plt.title('Number of Orders by Region')
plt.ylabel('Number of Orders')
plt.xlabel('Region')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # pie chart

# %%
sales['Region'].value_counts().unique()
# Out:
# array([1330, 1285,  719,  610,  534,  416,  106])

# %%
sales['Region'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
counts = sales['Region'].value_counts()
plt.pie(counts,labels=counts.unique(),autopct='%.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
counts = sales['Region'].value_counts()
plt.pie(counts,labels=counts.index,autopct='%.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
colors = sns.color_palette("Paired")
plt.pie(sales['Region'].value_counts(), autopct='%.0f%%',
        explode=[0,0,0,0,0,0,0], colors=sns.color_palette("Blues"))
plt.show()

# %%
colors = sns.color_palette('flare')
plt.pie(sales['Total_Revenue'].value_counts(),autopct= '%.0f%%',
      colors = colors)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # histogram

# %%
plt.hist(titanic['Age'], bins=7, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.title('Histogram of Titanic Passenger Ages')
plt.show()

# %%
sns.histplot(titanic['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.hist(titanic['Age'])
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # dist plot

# %%
sns.distplot(titanic['Age'])
# Out:
# /var/folders/bs/gqcp5y8s2jj09_z44vf1nkt40000gn/T/ipykernel_13834/3677708691.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(titanic['Age'],kde=True,bins=[20,40,60,80])
plt.title('Histrogram of age')
plt.show
# Out:
# /var/folders/bs/gqcp5y8s2jj09_z44vf1nkt40000gn/T/ipykernel_13834/3821086113.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'],kde=True,bins=[20,40,60,80])
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(titanic['Age'],kde=False,bins=[10,20,30,40])
plt.title('Histrogram of age')
plt.show
# Out:
# /var/folders/bs/gqcp5y8s2jj09_z44vf1nkt40000gn/T/ipykernel_13834/3399739962.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'],kde=False,bins=[10,20,30,40])
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # boxplot

# %%
sns.boxplot(x='Pclass', y='Age', hue='Sex', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
